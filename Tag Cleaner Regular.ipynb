# %%
########### Zotero Tag Cleaner: The Regular Clean ###########


from pyzotero import zotero

import time
import re
import requests
import pandas as pd
from io import BytesIO
pd.set_option('display.max_rows', 1000)



## Set up zotero API


# Add Library ID and Key here. If not a group library, change library type accordingly
library_id = "----"
api_key = "----" 

library_type = "group"

zot = zotero.Zotero(library_id, library_type, api_key)

# %%
### Get Tags ###

# %%
        
tags_df = zot.everything(zot.tags())

tags_df = pd.DataFrame(pd.unique(tags_df))  # account for duplicates due to zotero bugs with unique()

tags_df.rename(columns = {0:'Tag'}, inplace=True)


# not in whitelist
# Here, a whitelist of approved tags of our research group is used. Use your own whitelist instead!
# to bypass the google oauth process, the link from the browser window can be copied if sharing is activated

sharing_link = "https://docs.google.com/spreadsheets/d/1WfS1IsmEfS1k9l1fUcxAwz_Jv5o_N47htSFd8upycZ4/edit#gid=0
export_link = sharing_link.replace('/edit#gid=', '/export?format=csv&gid=')
r = requests.get(export_link)
data = r.content

df = pd.read_csv(BytesIO(data))
    
whitelist = df["Keyword"].str.strip()
whitelist = whitelist[~whitelist.str.contains("Generic")].reset_index(drop=True)

tags_df = tags_df[~tags_df.Tag.isin(whitelist)]


# not in generica list
# a list of allowed generica is used here. Such a list will be generated further down for future cleans
generica = pd.read_csv("Digidem_Generica_List_20190612.csv", names = "g", header = None)

tags_df = tags_df[~tags_df.Tag.isin(generica.g)].reset_index(drop=True)

print(tags_df)
# Out:
#                                                    Tag
# 0                                              Kittler
# 1                                                 Rosa
# 2                                                Keane
# 3                                              Gauchet
# 4                                          Rosanvallon
# 5                                   Fundamental Rights
# 6                                      user experience
# 7                                    content diversity
# 8                                    longitudinal data
# 9                                          Filterblase
# 10                                         Grundrechte
# 11                                          censorship
# 12                                      intermediaries
# 13                                   stereotype threat
# 14                                          censorware
# 15                                             twitter
# 16                                       co-regulation
# 17                                item-response models
# 18   Reports ; Internet ; Mass Phenomena; Communica...
# 19                                          legitimacy
# 20                                   freedom of speech
# 21                              ideal point estimation
# 22   Computer Science - Social and Information Netw...
# 23                                      accountability
# 24                                            ideology
# 25                                              search
# 26                                                bing
# 27                                       echo chambers
# 28                                         online news
# 29                                         Online News
# 30                      Social sciences in mass media.
# 31                                    Social sciences.
# 32                      Political Science / Censorship
# 33                                          Belief Gap
# 34   Political Science / Political Ideologies / Dem...
# 35                              Communication Studies.
# 36                                         Mass media.
# 37   Political Science / Political Process / Media ...
# 38                                      Communication.
# 39                                      Misperceptions
# 40         Political Science / Public Policy / General
# 41                                       Media Effects
# 42                                 Information Deficit
# 43                                    Media Sociology.
# 44                                    Popular Science.
# 45                            Popular Social Sciences.
# 46                                      Popular works.
# 47                                  information cocoon
# 48                                       self-selected
# 49                                           Democracy
# 50                             Political Communication
# 51                                 Political Discourse
# 52                                      Search Engines
# 53                                           Hypertext
# 54                                  Selective Exposure
# 55                                              Design
# 56                                       Filter bubble
# 57                                  Selective exposure
# 58                                        manipulation
# 59                              Value sensitive design
# 60                          personalised communication
# 61                                 Viewpoint diversity
# 62                                          Media Bias
# 63                                         pre-selcted
# 64                               Information Retrieval
# 65                                           algorithm
# 66                                        Social Media
# 67              Electronic Computers. Computer Science
# 68                                       Filter Bubble
# 69                                        Qa75.5-76.95
# 70                                           Diversity
# 71                                                Bias
# 72                                    Computer Science
# 73                                         Web Traffic
# 74                                        Polarization
# 75                                        Echo Chamber
# 76                                              Butler
# 77                                     Gouvermentality
# 78                                          Geschichte
# 79                             Wissenschaftsgeschichte
# 80                                           Statistik
# 81                                   Wissenssoziologie
# 82                           Politische Repräsentation
# 83                                   Meinungsforschung
# 84                                   Wissensgeschichte
# 85                            Geschichte der Statistik
# 86                     Visualisierung von Gesellschaft
# 87                                     imaginäre Räume
# 88                                Sozialwissenschaften
# 89                             political communication
# 90                                            blocking
# 91                                           filtering
# 92                                  Democractic Theory
# 93                                     self-regulation
# 94                                            internet
# 95               Political Science / Political Freedom
# 96                                        echo chamber
# 97                                       filter bubble
# 98                                     personalization
# 99                                  selective exposure
# 100                              freedom of expression
# 101                                recommender systems
# 102                                           Politics
# 103    Political Science / Political Process / General

# %%
### Make tags_replacement DF ###

# %%
# 1) replacements for upper/lower case typos

whitelist_lower = {"Replacement":whitelist, "lower":whitelist.str.lower()}
whitelist_lower_df = pd.DataFrame(whitelist_lower)

tags_lower = {"Tag":tags_df["Tag"], 
              "lower":tags_df["Tag"].str.lower()}
tags_lower_df = pd.DataFrame(tags_lower)

tags_replacement = pd.merge(tags_lower_df, whitelist_lower_df, on = "lower", how = "left")

del tags_replacement["lower"]

# drop correct tags (no need to replace!)
tags_replacement = tags_replacement[tags_replacement.Tag != tags_replacement.Replacement]

print(tags_replacement)
# Out:
#                                                    Tag     Replacement
# 0                                              Kittler             NaN
# 1                                                 Rosa             NaN
# 2                                                Keane             NaN
# 3                                              Gauchet             NaN
# 4                                          Rosanvallon             NaN
# 5                                   Fundamental Rights             NaN
# 6                                      user experience             NaN
# 7                                    content diversity             NaN
# 8                                    longitudinal data             NaN
# 9                                          Filterblase             NaN
# 10                                         Grundrechte             NaN
# 11                                          censorship             NaN
# 12                                      intermediaries  Intermediaries
# 13                                   stereotype threat             NaN
# 14                                          censorware             NaN
# 15                                             twitter             NaN
# 16                                       co-regulation             NaN
# 17                                item-response models             NaN
# 18   Reports ; Internet ; Mass Phenomena; Communica...             NaN
# 19                                          legitimacy      Legitimacy
# 20                                   freedom of speech             NaN
# 21                              ideal point estimation             NaN
# 22   Computer Science - Social and Information Netw...             NaN
# 23                                      accountability             NaN
# 24                                            ideology             NaN
# 25                                              search             NaN
# 26                                                bing             NaN
# 27                                       echo chambers             NaN
# 28                                         online news             NaN
# 29                                         Online News             NaN
# 30                      Social sciences in mass media.             NaN
# 31                                    Social sciences.             NaN
# 32                      Political Science / Censorship             NaN
# 33                                          Belief Gap             NaN
# 34   Political Science / Political Ideologies / Dem...             NaN
# 35                              Communication Studies.             NaN
# 36                                         Mass media.             NaN
# 37   Political Science / Political Process / Media ...             NaN
# 38                                      Communication.             NaN
# 39                                      Misperceptions             NaN
# 40         Political Science / Public Policy / General             NaN
# 41                                       Media Effects             NaN
# 42                                 Information Deficit             NaN
# 43                                    Media Sociology.             NaN
# 44                                    Popular Science.             NaN
# 45                            Popular Social Sciences.             NaN
# 46                                      Popular works.             NaN
# 47                                  information cocoon             NaN
# 48                                       self-selected             NaN
# 49                                           Democracy             NaN
# 50                             Political Communication             NaN
# 51                                 Political Discourse             NaN
# 52                                      Search Engines             NaN
# 53                                           Hypertext             NaN
# 54                                  Selective Exposure             NaN
# 55                                              Design             NaN
# 56                                       Filter bubble             NaN
# 57                                  Selective exposure             NaN
# 58                                        manipulation             NaN
# 59                              Value sensitive design             NaN
# 60                          personalised communication             NaN
# 61                                 Viewpoint diversity             NaN
# 62                                          Media Bias             NaN
# 63                                         pre-selcted             NaN
# 64                               Information Retrieval             NaN
# 65                                           algorithm             NaN
# 66                                        Social Media             NaN
# 67              Electronic Computers. Computer Science             NaN
# 68                                       Filter Bubble             NaN
# 69                                        Qa75.5-76.95             NaN
# 70                                           Diversity             NaN
# 71                                                Bias             NaN
# 72                                    Computer Science             NaN
# 73                                         Web Traffic             NaN
# 74                                        Polarization             NaN
# 75                                        Echo Chamber             NaN
# 76                                              Butler             NaN
# 77                                     Gouvermentality             NaN
# 78                                          Geschichte             NaN
# 79                             Wissenschaftsgeschichte             NaN
# 80                                           Statistik             NaN
# 81                                   Wissenssoziologie             NaN
# 82                           Politische Repräsentation             NaN
# 83                                   Meinungsforschung             NaN
# 84                                   Wissensgeschichte             NaN
# 85                            Geschichte der Statistik             NaN
# 86                     Visualisierung von Gesellschaft             NaN
# 87                                     imaginäre Räume             NaN
# 88                                Sozialwissenschaften             NaN
# 89                             political communication             NaN
# 90                                            blocking             NaN
# 91                                           filtering             NaN
# 92                                  Democractic Theory             NaN
# 93                                     self-regulation             NaN
# 94                                            internet             NaN
# 95               Political Science / Political Freedom             NaN
# 96                                        echo chamber             NaN
# 97                                       filter bubble             NaN
# 98                                     personalization             NaN
# 99                                  selective exposure             NaN
# 100                              freedom of expression             NaN
# 101                                recommender systems             NaN
# 102                                           Politics             NaN
# 103    Political Science / Political Process / General             NaN

# %%
# 2) replacement of synonyms [do not run/rerun without running upper/lower replacement first]

synonyms = df[["Keyword","Synonyme"]]
synonyms = synonyms[~synonyms.Keyword.str.contains("Generic")].reset_index(drop=True)

synonyms = (synonyms.drop("Synonyme", axis=1)
             .join
             (
             synonyms.Synonyme
             .str
             .split(",",expand=True)
             .stack()    
             .reset_index(drop=True, level=1)
             .rename("Synonyme")           
             ))

synonyms = synonyms[synonyms["Synonyme"] != " "]

synonyms["Synonyme"] = synonyms["Synonyme"].str.strip()

    # acount for case irregularities
synonyms_lower = {"Replacement":synonyms.Keyword, "lower":synonyms.Synonyme.str.lower()}
synonyms_lower_df = pd.DataFrame(synonyms_lower)

    # expand tags_replacement 
tags_lower_2 = {"Tag":tags_replacement["Tag"], 
                "lower":tags_replacement["Tag"].str.lower(), 
                "Replacement":tags_replacement["Replacement"]}
tags_lower_2_df = pd.DataFrame(tags_lower_2)

tags_replacement = pd.merge(tags_lower_2_df, synonyms_lower_df, on = "lower", how = "left")

tags_replacement.Replacement_x = tags_replacement.Replacement_x.combine_first(tags_replacement.Replacement_y)

del tags_replacement["lower"]

del tags_replacement["Replacement_y"]

tags_replacement.rename(columns = {"Replacement_x":"Replacement"}, inplace=True)

print(tags_replacement)
# Out:
#                                                    Tag     Replacement
# 0                                              Kittler             NaN
# 1                                                 Rosa             NaN
# 2                                                Keane             NaN
# 3                                              Gauchet             NaN
# 4                                          Rosanvallon             NaN
# 5                                   Fundamental Rights    Human Rights
# 6                                      user experience             NaN
# 7                                    content diversity             NaN
# 8                                    longitudinal data             NaN
# 9                                          Filterblase             NaN
# 10                                         Grundrechte    Human Rights
# 11                                          censorship             NaN
# 12                                      intermediaries  Intermediaries
# 13                                   stereotype threat             NaN
# 14                                          censorware             NaN
# 15                                             twitter             NaN
# 16                                       co-regulation             NaN
# 17                                item-response models             NaN
# 18   Reports ; Internet ; Mass Phenomena; Communica...             NaN
# 19                                          legitimacy      Legitimacy
# 20                                   freedom of speech             NaN
# 21                              ideal point estimation             NaN
# 22   Computer Science - Social and Information Netw...             NaN
# 23                                      accountability             NaN
# 24                                            ideology             NaN
# 25                                              search             NaN
# 26                                                bing             NaN
# 27                                       echo chambers   Fragmentation
# 28                                         online news             NaN
# 29                                         Online News             NaN
# 30                      Social sciences in mass media.             NaN
# 31                                    Social sciences.             NaN
# 32                      Political Science / Censorship             NaN
# 33                                          Belief Gap             NaN
# 34   Political Science / Political Ideologies / Dem...             NaN
# 35                              Communication Studies.             NaN
# 36                                         Mass media.             NaN
# 37   Political Science / Political Process / Media ...             NaN
# 38                                      Communication.             NaN
# 39                                      Misperceptions             NaN
# 40         Political Science / Public Policy / General             NaN
# 41                                       Media Effects             NaN
# 42                                 Information Deficit             NaN
# 43                                    Media Sociology.             NaN
# 44                                    Popular Science.             NaN
# 45                            Popular Social Sciences.             NaN
# 46                                      Popular works.             NaN
# 47                                  information cocoon             NaN
# 48                                       self-selected             NaN
# 49                                           Democracy             NaN
# 50                             Political Communication             NaN
# 51                                 Political Discourse             NaN
# 52                                      Search Engines  Intermediaries
# 53                                           Hypertext             NaN
# 54                                  Selective Exposure             NaN
# 55                                              Design             NaN
# 56                                       Filter bubble             NaN
# 57                                  Selective exposure             NaN
# 58                                        manipulation             NaN
# 59                              Value sensitive design             NaN
# 60                          personalised communication             NaN
# 61                                 Viewpoint diversity             NaN
# 62                                          Media Bias             NaN
# 63                                         pre-selcted             NaN
# 64                               Information Retrieval             NaN
# 65                                           algorithm      Algorithms
# 66                                        Social Media  Intermediaries
# 67              Electronic Computers. Computer Science             NaN
# 68                                       Filter Bubble             NaN
# 69                                        Qa75.5-76.95             NaN
# 70                                           Diversity             NaN
# 71                                                Bias             NaN
# 72                                    Computer Science             NaN
# 73                                         Web Traffic             NaN
# 74                                        Polarization   Fragmentation
# 75                                        Echo Chamber             NaN
# 76                                              Butler             NaN
# 77                                     Gouvermentality             NaN
# 78                                          Geschichte             NaN
# 79                             Wissenschaftsgeschichte             NaN
# 80                                           Statistik  Quantification
# 81                                   Wissenssoziologie       Knowledge
# 82                           Politische Repräsentation             NaN
# 83                                   Meinungsforschung             NaN
# 84                                   Wissensgeschichte             NaN
# 85                            Geschichte der Statistik             NaN
# 86                     Visualisierung von Gesellschaft             NaN
# 87                                     imaginäre Räume             NaN
# 88                                Sozialwissenschaften             NaN
# 89                             political communication             NaN
# 90                                            blocking             NaN
# 91                                           filtering             NaN
# 92                                  Democractic Theory             NaN
# 93                                     self-regulation             NaN
# 94                                            internet             NaN
# 95               Political Science / Political Freedom             NaN
# 96                                        echo chamber             NaN
# 97                                       filter bubble             NaN
# 98                                     personalization             NaN
# 99                                  selective exposure             NaN
# 100                              freedom of expression             NaN
# 101                                recommender systems             NaN
# 102                                           Politics             NaN
# 103    Political Science / Political Process / General             NaN

# %%
# 3) auto-check for synonyms within Tags
            # [greediest method, may overwrite replacements already in place]

def foo(tag):
    for keyword in whitelist:
        if keyword.lower() in tag.lower():
            return keyword

tags_replacement["Replacement"].loc[pd.isnull(tags_replacement["Replacement"])] = tags_replacement["Tag"].apply(foo)
print(tags_replacement)
# Out:
#                                                    Tag     Replacement
# 0                                              Kittler            None
# 1                                                 Rosa            None
# 2                                                Keane            None
# 3                                              Gauchet            None
# 4                                          Rosanvallon            None
# 5                                   Fundamental Rights    Human Rights
# 6                                      user experience            None
# 7                                    content diversity            None
# 8                                    longitudinal data            None
# 9                                          Filterblase            None
# 10                                         Grundrechte    Human Rights
# 11                                          censorship            None
# 12                                      intermediaries  Intermediaries
# 13                                   stereotype threat            None
# 14                                          censorware            None
# 15                                             twitter            None
# 16                                       co-regulation      Regulation
# 17                                item-response models            None
# 18   Reports ; Internet ; Mass Phenomena; Communica...            None
# 19                                          legitimacy      Legitimacy
# 20                                   freedom of speech            None
# 21                              ideal point estimation            None
# 22   Computer Science - Social and Information Netw...            None
# 23                                      accountability            None
# 24                                            ideology            None
# 25                                              search            None
# 26                                                bing            None
# 27                                       echo chambers   Fragmentation
# 28                                         online news            None
# 29                                         Online News            None
# 30                      Social sciences in mass media.            None
# 31                                    Social sciences.            None
# 32                      Political Science / Censorship            None
# 33                                          Belief Gap            None
# 34   Political Science / Political Ideologies / Dem...            None
# 35                              Communication Studies.            None
# 36                                         Mass media.            None
# 37   Political Science / Political Process / Media ...            None
# 38                                      Communication.            None
# 39                                      Misperceptions            None
# 40         Political Science / Public Policy / General            None
# 41                                       Media Effects            None
# 42                                 Information Deficit            None
# 43                                    Media Sociology.            None
# 44                                    Popular Science.            None
# 45                            Popular Social Sciences.            None
# 46                                      Popular works.            None
# 47                                  information cocoon            None
# 48                                       self-selected            None
# 49                                           Democracy            None
# 50                             Political Communication            None
# 51                                 Political Discourse            None
# 52                                      Search Engines  Intermediaries
# 53                                           Hypertext            None
# 54                                  Selective Exposure            None
# 55                                              Design            None
# 56                                       Filter bubble            None
# 57                                  Selective exposure            None
# 58                                        manipulation            None
# 59                              Value sensitive design            None
# 60                          personalised communication            None
# 61                                 Viewpoint diversity            None
# 62                                          Media Bias            None
# 63                                         pre-selcted            None
# 64                               Information Retrieval            None
# 65                                           algorithm      Algorithms
# 66                                        Social Media  Intermediaries
# 67              Electronic Computers. Computer Science            None
# 68                                       Filter Bubble            None
# 69                                        Qa75.5-76.95            None
# 70                                           Diversity            None
# 71                                                Bias            None
# 72                                    Computer Science            None
# 73                                         Web Traffic            None
# 74                                        Polarization   Fragmentation
# 75                                        Echo Chamber            None
# 76                                              Butler            None
# 77                                     Gouvermentality            None
# 78                                          Geschichte            None
# 79                             Wissenschaftsgeschichte            None
# 80                                           Statistik  Quantification
# 81                                   Wissenssoziologie       Knowledge
# 82                           Politische Repräsentation            None
# 83                                   Meinungsforschung            None
# 84                                   Wissensgeschichte            None
# 85                            Geschichte der Statistik            None
# 86                     Visualisierung von Gesellschaft            None
# 87                                     imaginäre Räume            None
# 88                                Sozialwissenschaften            None
# 89                             political communication            None
# 90                                            blocking            None
# 91                                           filtering            None
# 92                                  Democractic Theory            None
# 93                                     self-regulation      Regulation
# 94                                            internet            None
# 95               Political Science / Political Freedom            None
# 96                                        echo chamber            None
# 97                                       filter bubble            None
# 98                                     personalization            None
# 99                                  selective exposure            None
# 100                              freedom of expression            None
# 101                                recommender systems            None
# 102                                           Politics            None
# 103    Political Science / Political Process / General            None

# %%
# 4) export tags_replacement for hand-checking 

tags_replacement.to_excel("tags_replacement.xlsx")

# %%
# 5) re-import hand-checked list

tags_replacement_edit = pd.read_excel("tags_replacement.xlsx")

# drop generica (authors, theories, technologies, policy fields stay as they are)
tags_replacement_edit = tags_replacement_edit[(tags_replacement_edit.Replacement != "author") &
                                             (tags_replacement_edit.Replacement != "central_actor") &
                                             (tags_replacement_edit.Replacement != "concrete_tech") &
                                             (tags_replacement_edit.Replacement != "method")&
                                              (tags_replacement_edit.Replacement != "policy_field") &
                                             (tags_replacement_edit.Replacement != "theory/school")].reset_index(drop=True)

# strip potential whitespace from replacements, just in case
tags_replacement_edit["Replacement"] = tags_replacement_edit["Replacement"].str.strip()

print(tags_replacement_edit)
# Out:
#                                                   Tag            Replacement
# 0                                  Fundamental Rights           Human Rights
# 1                                     user experience                    NaN
# 2                                   content diversity                    NaN
# 3                                   longitudinal data           Panel Survey
# 4                                         Filterblase          Fragmentation
# 5                                         Grundrechte           Human Rights
# 6                                          censorship     Power & Domination
# 7                                      intermediaries         Intermediaries
# 8                                   stereotype threat                    NaN
# 9                                          censorware                    NaN
# 10                                            twitter                Twitter
# 11                                      co-regulation             Regulation
# 12                               item-response models   Quantitative Methods
# 13  Reports ; Internet ; Mass Phenomena; Communica...                    NaN
# 14                                         legitimacy             Legitimacy
# 15                                  freedom of speech                    NaN
# 16                             ideal point estimation   Quantitative Methods
# 17  Computer Science - Social and Information Netw...                    NaN
# 18                                     accountability                    NaN
# 19                                           ideology                    NaN
# 20                                             search                    NaN
# 21                                               bing                    NaN
# 22                                      echo chambers          Fragmentation
# 23                                        online news             Journalism
# 24                                        Online News             Journalism
# 25                     Social sciences in mass media.                    NaN
# 26                                   Social sciences.                    NaN
# 27                     Political Science / Censorship                    NaN
# 28                                         Belief Gap                    NaN
# 29  Political Science / Political Ideologies / Dem...                    NaN
# 30                             Communication Studies.  Communication Studies
# 31                                        Mass media.         Intermediaries
# 32  Political Science / Political Process / Media ...                    NaN
# 33                                     Communication.                    NaN
# 34                                     Misperceptions                    NaN
# 35        Political Science / Public Policy / General                    NaN
# 36                                      Media Effects         Intermediaries
# 37                                Information Deficit                    NaN
# 38                                   Media Sociology.                    NaN
# 39                                   Popular Science.                    NaN
# 40                           Popular Social Sciences.                    NaN
# 41                                     Popular works.                    NaN
# 42                                 information cocoon                    NaN
# 43                                      self-selected                    NaN
# 44                                          Democracy                    NaN
# 45                            Political Communication  Communication Studies
# 46                                Political Discourse                    NaN
# 47                                     Search Engines         Intermediaries
# 48                                          Hypertext                    NaN
# 49                                 Selective Exposure                    NaN
# 50                                             Design                    NaN
# 51                                      Filter bubble          Fragmentation
# 52                                 Selective exposure                    NaN
# 53                                       manipulation                    NaN
# 54                             Value sensitive design                    NaN
# 55                         personalised communication                    NaN
# 56                                Viewpoint diversity                    NaN
# 57                                         Media Bias          Fragmentation
# 58                                        pre-selcted                    NaN
# 59                              Information Retrieval                    NaN
# 60                                          algorithm             Algorithms
# 61                                       Social Media         Intermediaries
# 62             Electronic Computers. Computer Science                    NaN
# 63                                      Filter Bubble          Fragmentation
# 64                                       Qa75.5-76.95                    NaN
# 65                                          Diversity                    NaN
# 66                                               Bias                    NaN
# 67                                   Computer Science                    NaN
# 68                                        Web Traffic                    NaN
# 69                                       Polarization          Fragmentation
# 70                                       Echo Chamber          Fragmentation
# 71                                    Gouvermentality        Governmentality
# 72                                         Geschichte                    NaN
# 73                            Wissenschaftsgeschichte              Knowledge
# 74                                          Statistik         Quantification
# 75                                  Wissenssoziologie              Knowledge
# 76                          Politische Repräsentation         Representation
# 77                                  Meinungsforschung         Representation
# 78                                  Wissensgeschichte              Knowledge
# 79                           Geschichte der Statistik         Quantification
# 80                    Visualisierung von Gesellschaft          Visualization
# 81                                    imaginäre Räume                    NaN
# 82                               Sozialwissenschaften                    NaN
# 83                            political communication  Communication Studies
# 84                                           blocking                    NaN
# 85                                          filtering                    NaN
# 86                                 Democractic Theory      Democratic Theory
# 87                                    self-regulation             Regulation
# 88                                           internet                    NaN
# 89              Political Science / Political Freedom                    NaN
# 90                                       echo chamber          Fragmentation
# 91                                      filter bubble          Fragmentation
# 92                                    personalization                    NaN
# 93                                 selective exposure                    NaN
# 94                              freedom of expression                    NaN
# 95                                recommender systems         Intermediaries
# 96                                           Politics                    NaN
# 97    Political Science / Political Process / General                    NaN

# %%
### Loop through entries of library and replace Tags ###

# %%
# update zot - just in case
zot = zotero.Zotero(library_id, library_type, api_key)        

# replace tags
replace = tags_replacement_edit.loc[pd.notnull(tags_replacement_edit["Replacement"])]
for index, row in replace.iterrows():
#for index, row in test.iterrows(): 
    # get item with Tag
    items = zot.everything(zot.items(tag = row["Tag"]))
    # modify tags for items
    for item in items:      # item modification chunked in single API calls, not affected by 50 items-per-call limit
        print("Replace: %s -> %s" % (row["Tag"], row["Replacement"]))
        zot.add_tags(item, row["Replacement"])
    time.sleep(2)       # short rest between tags to minimize API errors
# Out:
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: intermediaries -> Intermediaries
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: twitter -> Twitter
# Replace: legitimacy -> Legitimacy
# Replace: legitimacy -> Legitimacy
# Replace: legitimacy -> Legitimacy
# Replace: legitimacy -> Legitimacy
# Replace: legitimacy -> Legitimacy
# Replace: legitimacy -> Legitimacy
# Replace: legitimacy -> Legitimacy
# Replace: legitimacy -> Legitimacy
# Replace: legitimacy -> Legitimacy
# Replace: legitimacy -> Legitimacy
# Replace: legitimacy -> Legitimacy
# Replace: legitimacy -> Legitimacy
# Replace: legitimacy -> Legitimacy
# Replace: legitimacy -> Legitimacy
# Replace: legitimacy -> Legitimacy
# Replace: legitimacy -> Legitimacy
# Replace: legitimacy -> Legitimacy
# Replace: legitimacy -> Legitimacy
# Replace: legitimacy -> Legitimacy
# Replace: legitimacy -> Legitimacy
# Replace: legitimacy -> Legitimacy
# Replace: legitimacy -> Legitimacy
# Replace: legitimacy -> Legitimacy
# Replace: legitimacy -> Legitimacy
# Replace: legitimacy -> Legitimacy
# Replace: legitimacy -> Legitimacy
# Replace: legitimacy -> Legitimacy
# Replace: legitimacy -> Legitimacy
# Replace: legitimacy -> Legitimacy
# Replace: legitimacy -> Legitimacy
# Replace: legitimacy -> Legitimacy
# Replace: legitimacy -> Legitimacy
# Replace: legitimacy -> Legitimacy
# Replace: legitimacy -> Legitimacy
# Replace: legitimacy -> Legitimacy
# Replace: legitimacy -> Legitimacy
# Replace: legitimacy -> Legitimacy
# Replace: legitimacy -> Legitimacy
# Replace: legitimacy -> Legitimacy
# Replace: legitimacy -> Legitimacy
# Replace: legitimacy -> Legitimacy
# Replace: legitimacy -> Legitimacy
# Replace: legitimacy -> Legitimacy
# Replace: legitimacy -> Legitimacy
# Replace: legitimacy -> Legitimacy
# Replace: legitimacy -> Legitimacy
# Replace: legitimacy -> Legitimacy
# Replace: legitimacy -> Legitimacy
# Replace: legitimacy -> Legitimacy
# Replace: legitimacy -> Legitimacy
# Replace: legitimacy -> Legitimacy
# Replace: legitimacy -> Legitimacy
# Replace: legitimacy -> Legitimacy
# Replace: legitimacy -> Legitimacy
# Replace: legitimacy -> Legitimacy
# Replace: legitimacy -> Legitimacy
# Replace: legitimacy -> Legitimacy
# Replace: legitimacy -> Legitimacy
# Replace: legitimacy -> Legitimacy
# Replace: legitimacy -> Legitimacy
# Replace: legitimacy -> Legitimacy
# Replace: legitimacy -> Legitimacy
# Replace: legitimacy -> Legitimacy
# Replace: legitimacy -> Legitimacy
# Replace: legitimacy -> Legitimacy
# Replace: legitimacy -> Legitimacy
# Replace: legitimacy -> Legitimacy
# Replace: legitimacy -> Legitimacy
# Replace: legitimacy -> Legitimacy
# Replace: legitimacy -> Legitimacy
# Replace: legitimacy -> Legitimacy
# Replace: Politische Repräsentation -> Representation

# %%
# delete old Tags (including the ones with replacement)

delete = tags_replacement_edit["Tag"].tolist()

# loop to keep track which ones get deleted without replacement
for index, row in tags_replacement_edit.iterrows():
    if pd.isnull(row["Replacement"]):
        print("Delete: %s" % row["Tag"])


# split deletion of tags into chunks of 50 to adhere to the 50-tags-deleted-per-call API limit                
def chunker(seq, size):
    return (seq[pos:pos + size] for pos in range(0, len(seq), size))
for i in chunker(delete, 50):
    zot.delete_tags(*i)
# Out:
# Delete: user experience
# Delete: content diversity
# Delete: stereotype threat
# Delete: censorware
# Delete: Reports ; Internet ; Mass Phenomena; Communication ; Article;
# Delete: freedom of speech
# Delete: Computer Science - Social and Information Networks
# Delete: accountability
# Delete: ideology
# Delete: search
# Delete: bing
# Delete: Social sciences in mass media.
# Delete: Social sciences.
# Delete: Political Science / Censorship
# Delete: Belief Gap
# Delete: Political Science / Political Ideologies / Democracy
# Delete: Political Science / Political Process / Media & Internet
# Delete: Communication.
# Delete: Misperceptions
# Delete: Political Science / Public Policy / General
# Delete: Information Deficit
# Delete: Media Sociology.
# Delete: Popular Science.
# Delete: Popular Social Sciences.
# Delete: Popular works.
# Delete: information cocoon
# Delete: self-selected
# Delete: Democracy
# Delete: Political Discourse
# Delete: Hypertext
# Delete: Selective Exposure
# Delete: Design
# Delete: Selective exposure
# Delete: manipulation
# Delete: Value sensitive design
# Delete: personalised communication
# Delete: Viewpoint diversity
# Delete: pre-selcted
# Delete: Information Retrieval
# Delete: Electronic Computers. Computer Science
# Delete: Qa75.5-76.95
# Delete: Diversity
# Delete: Bias
# Delete: Computer Science
# Delete: Web Traffic
# Delete: Geschichte
# Delete: imaginäre Räume
# Delete: Sozialwissenschaften
# Delete: blocking
# Delete: filtering
# Delete: internet
# Delete: Political Science / Political Freedom
# Delete: personalization
# Delete: selective exposure
# Delete: freedom of expression
# Delete: Politics
# Delete: Political Science / Political Process / General

# %%
### Check Back ###

# %%
        
tags_df = zot.everything(zot.tags())

tags_df = pd.DataFrame(pd.unique(tags_df))  # account for duplicates due to zotero bugs with unique()

tags_df.rename(columns = {0:'Tag'}, inplace=True)


# not in whitelist

sharing_link = "https://docs.google.com/spreadsheets/d/18n09G6fduidnWz0wzP1nWqMbXJW-AFkhL-kie-zZIYM/edit#gid=0"
export_link = sharing_link.replace('/edit#gid=', '/export?format=csv&gid=')
r = requests.get(export_link)
data = r.content

df = pd.read_csv(BytesIO(data))
    
whitelist = df["Keyword"].str.strip()
whitelist = whitelist[~whitelist.str.contains("Generic")].reset_index(drop=True)

tags_df = tags_df[~tags_df.Tag.isin(whitelist)]


# not in generica list

generica = pd.read_csv("Digidem_Generica_List_20190612.csv", names = "g", header = None)

tags_df = tags_df[~tags_df.Tag.isin(generica.g)].reset_index(drop=True)

print(tags_df)
# Out:
#            Tag
# 0      Kittler
# 1         Rosa
# 2        Keane
# 3      Gauchet
# 4  Rosanvallon
# 5       Butler

# %%
### Add new Generica ###

# %%
new_generica = pd.read_excel("tags_replacement.xlsx")

new_generica["Replacement"] = new_generica["Replacement"].str.strip()

# get generica (authors, theories, technologies, policy fields stay as they are)
new_generica = new_generica[(new_generica.Replacement == "author") |
                                             (new_generica.Replacement == "central_actor") |
                                             (new_generica.Replacement == "concrete_tech") |
                                             (new_generica.Replacement == "method")|
                                              (new_generica.Replacement == "policy_field") |
                                             (new_generica.Replacement == "theory/school")].reset_index(drop=True)

print(new_generica["Tag"])
# Out:
# 0        Kittler
# 1           Rosa
# 2          Keane
# 3        Gauchet
# 4    Rosanvallon
# 5         Butler
# Name: Tag, dtype: object

# %%
generica_update = generica["g"].append(new_generica["Tag"], ignore_index = True)
print(generica_update)
# Out:
# 0                              Adorno
# 1                              Anders
# 2                           Appelbaum
# 3                              Arendt
# 4                               Bacon
# 5                               Barad
# 6                                Beck
# 7                            Benhabib
# 8                            Benjamin
# 9                             Bentham
# 10                             Berger
# 11                          Boltanski
# 12                           Bourdieu
# 13                              Buber
# 14                              Cohen
# 15                            Coleman
# 16                           Dahlgren
# 17                         Dahrendorf
# 18                             Debord
# 19                            Deleuze
# 20                            Derrida
# 21                              Dewey
# 22                            Drexler
# 23                            Dworkin
# 24                              Elias
# 25                           Foucault
# 26                             Fraser
# 27                             Gamson
# 28                            Giddens
# 29                            Goffman
# 30                            Gramsci
# 31                           Habermas
# 32                              Hardt
# 33                              Hegel
# 34                          Heidegger
# 35                            Honneth
# 36                            Husserl
# 37                             Huxley
# 38                               Kant
# 39                        Kierkegaard
# 40                          Koschorke
# 41                             Laclau
# 42                             Latour
# 43                             Lefort
# 44                            Luckács
# 45                           Luckmann
# 46                            Luhmann
# 47                          Luxemburg
# 48                            Marcuse
# 49                               Marx
# 50                            Melucci
# 51                              Morus
# 52                             Mouffe
# 53                              Negri
# 54                          Nietzsche
# 55                         Nissenbaum
# 56                              Nowak
# 57                             Orwell
# 58                            Parsons
# 59                             Platon
# 60                            Postman
# 61                           Rancière
# 62                              Rawls
# 63                              Rorty
# 64                            Schmitt
# 65                             Schütz
# 66                             Simmel
# 67                           Simondon
# 68                            Spencer
# 69                            Strauss
# 70                           Thévenot
# 71                        Tocqueville
# 72                              Weber
# 73                         Weizenbaum
# 74                              White
# 75                             Wiener
# 76                           Williams
# 77                          Winnicott
# 78                              Wolin
# 79                              Žižek
# 80                              Hayek
# 81          Internet Governance Forum
# 82                                AfD
# 83                             Amazon
# 84                          Anonymous
# 85                              Apple
# 86                            Assange
# 87                         Change.org
# 88                Chaos Computer Club
# 89                               ebay
# 90                                 EU
# 91                           Facebook
# 92                                FCC
# 93                             Flickr
# 94                             Google
# 95                                IBM
# 96                              ICANN
# 97                                IGF
# 98                          indymedia
# 99                          Instagram
# 100                         Microsoft
# 101                               NSA
# 102                            Occupy
# 103                           Pay Pal
# 104                           Snowden
# 105                            Tumblr
# 106                           Twitter
# 107                              Uber
# 108                             Weibo
# 109                         WikiLeaks
# 110                         Wikipedia
# 111                               WTO
# 112                           YouTube
# 113                    Microtargeting
# 114                 Augmented Reality
# 115              Biometric Technology
# 116                           Bitcoin
# 117                        Blockchain
# 118                              CCTV
# 119                              DDoS
# 120                               DNS
# 121                             Drone
# 122                             Memes
# 123                               Tor
# 124                        Case Study
# 125                  Content Analysis
# 126                Discourse Analysis
# 127                Experimental Study
# 128                        Interviews
# 129                 Metaphor Analysis
# 130                     Mixed Methods
# 131                  Network Analysis
# 132                      Panel Survey
# 133                   Policy Analysis
# 134              Quantitative Methods
# 135                       Text Mining
# 136                    Topic Modeling
# 137              Environmental Policy
# 138                      Media Policy
# 139                     Public Policy
# 140                          Security
# 141                          Feminism
# 142                      Field Theory
# 143            Social Movement Theory
# 144                  Authoritarianism
# 145          Collective Action Theory
# 146             Communication Studies
# 147                  Communitarianism
# 148     Computational Social Sciences
# 149                    Constructivism
# 150                   Cosmopolitanism
# 151              Counterpublic Theory
# 152                   Critical Theory
# 153                Cultivation Theory
# 154                  Cultural Studies
# 155    Deliberative Democratic Theory
# 156                       Ethnography
# 157                     Formal Theory
# 158                  Frankfurt School
# 159                   Grounded Theory
# 160                Information Theory
# 161            Infrastructure Studies
# 162           International Relations
# 163                        Journalism
# 164                        Liberalism
# 165                           Marxism
# 166                       Materialism
# 167                      Media Theory
# 168                  Moral Philosophy
# 169                     Neoliberalism
# 170                    Network Theory
# 171                   New Materialism
# 172                     Phenomenology
# 173                        Philosophy
# 174                         Pluralism
# 175                 Political Economy
# 176                          Populism
# 177                Post-Structuralism
# 178                        Pragmatism
# 179                 Radical Democracy
# 180                           Realism
# 181                     Republicanism
# 182                               STS
# 183           Symbolic Interactionism
# 184                    Systems Theory
# 185                       Utilitarism
# 186                Black Lives Matter
# 187                           Bergson
# 188                          Castells
# 189                             Milan
# 190                            Reddit
# 191           Economics of Convention
# 192           Social Movements Theory
# 193                   Cultural Theory
# 194                 Democratic Theory
# 195                      Hermeneutics
# 196              Neo-Institutionalism
# 197                       Afghanistan
# 198                           Albania
# 199                           Algeria
# 200                           Andorra
# 201                            Angola
# 202                           Antigua
# 203                         Argentina
# 204                           Armenia
# 205                         Australia
# 206                           Austria
# 207                        Azerbaijan
# 208                           Bahamas
# 209                           Bahrain
# 210                        Bangladesh
# 211                          Barbados
# 212                           Belarus
# 213                           Belgium
# 214                            Belize
# 215                             Benin
# 216                            Bhutan
# 217                            Bissau
# 218                           Bolivia
# 219                            Bosnia
# 220                          Botswana
# 221                            Brazil
# 222                           British
# 223                            Brunei
# 224                          Bulgaria
# 225                           Burkina
# 226                             Burma
# 227                           Burundi
# 228                          Cambodia
# 229                          Cameroon
# 230                            Canada
# 231                        Cape Verde
# 232          Central African Republic
# 233                              Chad
# 234                             Chile
# 235                             China
# 236                          Colombia
# 237                           Comoros
# 238                             Congo
# 239                        Costa Rica
# 240                           Croatia
# 241                              Cuba
# 242                            Cyprus
# 243                             Czech
# 244                           Denmark
# 245                          Djibouti
# 246                          Dominica
# 247                        East Timor
# 248                           Ecuador
# 249                             Egypt
# 250                       El Salvador
# 251                           Emirate
# 252                           England
# 253                           Eritrea
# 254                           Estonia
# 255                          Ethiopia
# 256                              Fiji
# 257                           Finland
# 258                            France
# 259                             Gabon
# 260                            Gambia
# 261                           Georgia
# 262                           Germany
# 263                             Ghana
# 264                            Greece
# 265                           Grenada
# 266                        Grenadines
# 267                         Guatemala
# 268                            Guinea
# 269                            Guyana
# 270                             Haiti
# 271                       Herzegovina
# 272                          Honduras
# 273                           Hungary
# 274                           Iceland
# 275                             India
# 276                         Indonesia
# 277                              Iran
# 278                              Iraq
# 279                           Ireland
# 280                            Israel
# 281                             Italy
# 282                       Ivory Coast
# 283                           Jamaica
# 284                             Japan
# 285                            Jordan
# 286                        Kazakhstan
# 287                             Kenya
# 288                          Kiribati
# 289                             Korea
# 290                            Kosovo
# 291                            Kuwait
# 292                        Kyrgyzstan
# 293                              Laos
# 294                            Latvia
# 295                           Lebanon
# 296                           Lesotho
# 297                           Liberia
# 298                             Libya
# 299                     Liechtenstein
# 300                         Lithuania
# 301                        Luxembourg
# 302                         Macedonia
# 303                        Madagascar
# 304                            Malawi
# 305                          Malaysia
# 306                          Maldives
# 307                              Mali
# 308                             Malta
# 309                          Marshall
# 310                        Mauritania
# 311                         Mauritius
# 312                            Mexico
# 313                        Micronesia
# 314                           Moldova
# 315                            Monaco
# 316                          Mongolia
# 317                        Montenegro
# 318                           Morocco
# 319                        Mozambique
# 320                           Myanmar
# 321                           Namibia
# 322                             Nauru
# 323                             Nepal
# 324                       Netherlands
# 325                       New Zealand
# 326                         Nicaragua
# 327                             Niger
# 328                           Nigeria
# 329                            Norway
# 330                              Oman
# 331                          Pakistan
# 332                             Palau
# 333                            Panama
# 334                             Papua
# 335                          Paraguay
# 336                              Peru
# 337                       Philippines
# 338                            Poland
# 339                          Portugal
# 340                             Qatar
# 341                           Romania
# 342                            Russia
# 343                            Rwanda
# 344                             Samoa
# 345                        San Marino
# 346                          Sao Tome
# 347                      Saudi Arabia
# 348                           Senegal
# 349                            Serbia
# 350                        Seychelles
# 351                      Sierra Leone
# 352                         Singapore
# 353                          Slovakia
# 354                          Slovenia
# 355                           Solomon
# 356                           Somalia
# 357                      South Africa
# 358                       South Sudan
# 359                             Spain
# 360                         Sri Lanka
# 361                         St. Kitts
# 362                         St. Lucia
# 363                          St Kitts
# 364                          St Lucia
# 365                       Saint Kitts
# 366                       Santa Lucia
# 367                             Sudan
# 368                          Suriname
# 369                         Swaziland
# 370                            Sweden
# 371                       Switzerland
# 372                             Syria
# 373                            Taiwan
# 374                        Tajikistan
# 375                          Tanzania
# 376                          Thailand
# 377                            Tobago
# 378                              Togo
# 379                             Tonga
# 380                          Trinidad
# 381                           Tunisia
# 382                            Turkey
# 383                      Turkmenistan
# 384                            Tuvalu
# 385                            Uganda
# 386                           Ukraine
# 387                                UK
# 388                               USA
# 389                           Uruguay
# 390                        Uzbekistan
# 391                           Vanuatu
# 392                           Vatican
# 393                         Venezuela
# 394                           Vietnam
# 395                             Yemen
# 396                            Zambia
# 397                          Zimbabwe
# 398                    Arab Countries
# 399                            Africa
# 400                       Scandinavia
# 401                              APIs
# 402                            NetzDG
# 403                              GDPR
# 404                       South Korea
# 405                       Middle East
# 406                     Latin America
# 407                            Brexit
# 408                              Asia
# 409                            Europe
# 410                       Arab Spring
# 411                               ANT
# 412                           Kittler
# 413                              Rosa
# 414                             Keane
# 415                           Gauchet
# 416                       Rosanvallon
# 417                            Butler
# dtype: object

# %%
date = time.strftime("%Y%m%d")

generica_update.to_csv("Digidem_Generica_List_" + date + ".csv")
